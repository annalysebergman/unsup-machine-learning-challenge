# %% [markdown]
# # Unsupervised Machine Learning Challenge

# %% [markdown]
# ### Part 1: Prepare the data

# %%
import pandas as pd
import pathlib as path
from sklearn.preprocessing import StandardScaler
import numpy as np
import sklearn.cluster as KMeans
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# %%
# read in dataset into pandas dataframe
myopia_df = pd.read_csv("myopia.csv")
myopia_df
# Out:
#      AGE  SPHEQ         AL    ACD     LT    VCD  SPORTHR  READHR  COMPHR  \
# 0      6 -0.052  21.889999  3.690  3.498  14.70       45       8       0
# 1      6  0.608  22.379999  3.702  3.392  15.29        4       0       1
# 2      6  1.179  22.490000  3.462  3.514  15.52       14       0       2
# 3      6  0.525  22.200001  3.862  3.612  14.73       18      11       0
# 4      5  0.697  23.290001  3.676  3.454  16.16       14       0       0
# ..   ...    ...        ...    ...    ...    ...      ...     ...     ...
# 613    6  0.678  22.400000  3.663  3.803  14.93        2       0       7
# 614    6  0.665  22.500000  3.570  3.378  15.56        6       0       1
# 615    6  1.834  22.940001  3.624  3.424  15.89        8       0       0
# 616    6  0.665  21.920000  3.688  3.598  14.64       12       2       1
# 617    6  0.802  22.260000  3.530  3.484  15.25       25       0       2
#
#      STUDYHR  TVHR  DIOPTERHR  MOMMY  DADMY  MYOPIC
# 0          0    10         34      1      1       1
# 1          1     7         12      1      1       0
# 2          0    10         14      0      0       0
# 3          0     4         37      0      1       1
# 4          0     4          4      1      0       0
# ..       ...   ...        ...    ...    ...     ...
# 613        3    14         37      1      0       1
# 614        0     8         10      1      1       0
# 615        0     4          4      1      1       0
# 616        0    15         23      0      0       0
# 617        0    10         14      1      1       0
#
# [618 rows x 15 columns]

# %%
# Remove the "MYOPIC" column from the dataset.
myopia_df = myopia_df.drop(columns = ['MYOPIC'])
myopia_df
# Out:
#      AGE  SPHEQ         AL    ACD     LT    VCD  SPORTHR  READHR  COMPHR  \
# 0      6 -0.052  21.889999  3.690  3.498  14.70       45       8       0
# 1      6  0.608  22.379999  3.702  3.392  15.29        4       0       1
# 2      6  1.179  22.490000  3.462  3.514  15.52       14       0       2
# 3      6  0.525  22.200001  3.862  3.612  14.73       18      11       0
# 4      5  0.697  23.290001  3.676  3.454  16.16       14       0       0
# ..   ...    ...        ...    ...    ...    ...      ...     ...     ...
# 613    6  0.678  22.400000  3.663  3.803  14.93        2       0       7
# 614    6  0.665  22.500000  3.570  3.378  15.56        6       0       1
# 615    6  1.834  22.940001  3.624  3.424  15.89        8       0       0
# 616    6  0.665  21.920000  3.688  3.598  14.64       12       2       1
# 617    6  0.802  22.260000  3.530  3.484  15.25       25       0       2
#
#      STUDYHR  TVHR  DIOPTERHR  MOMMY  DADMY
# 0          0    10         34      1      1
# 1          1     7         12      1      1
# 2          0    10         14      0      0
# 3          0     4         37      0      1
# 4          0     4          4      1      0
# ..       ...   ...        ...    ...    ...
# 613        3    14         37      1      0
# 614        0     8         10      1      1
# 615        0     4          4      1      1
# 616        0    15         23      0      0
# 617        0    10         14      1      1
#
# [618 rows x 14 columns]

# %%
# standarize columns
scaler = StandardScaler()
myopia_scaled = scaler.fit_transform(myopia_df)

# %% [markdown]
# ### Part 2: Apply Dimensionality Reduction

# %%
# Perform dimensionality reduction with PCA. How did the number of the features change?
pca = PCA(n_components=.9)
myopia_pca = pca.fit_transform(myopia_scaled)

# %%
# Further reduce the dataset dimensions with t-SNE and visually inspect the results. 
# To do this, run t-SNE on the principal components, which is the output of the PCA transformation.
tsne = TSNE(learning_rate=250)
myopia_tsne = tsne.fit_transform(myopia_pca)
myopia_tsne.shape
# Out:
# C:\Users\annal\anaconda3\lib\site-packages\sklearn\manifold\_t_sne.py:780: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# (618, 2)

# %%
# Create a scatter plot of the t-SNE output. Are there distinct clusters?
plt.scatter(myopia_tsne[:,0], myopia_tsne[:,1])
plt.show()

# %% [markdown]
# ### Part 3: Perform a Cluster Analysis with K-means

# %%
# Create an elbow plot to identify the best number of clusters. 
inertia = []
k = list(range(1, 11))

for i in k:
    km = KMeans(n_clusters=i, random_state=1)
    km.fit(data_transformed)
    inertia.append(km.inertia_)
    
elbow_data = {"k": k, "inertia": inertia}
myopia_elbow = pd.DataFrame(elbow_data)
myopia_elbow.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_51116\3938500160.py in <module>
#       4
#       5 for i in k:
# ----> 6     km = KMeans(n_clusters=i, random_state=1)
#       7     km.fit(data_transformed)
#       8     inertia.append(km.inertia_)
#
# TypeError: 'module' object is not callable

# %%
# Plot the elbow curve to find the best candidate(s) for k
plt.plot(myopia_elbow['k'], myopia_elbow['inertia'])
plt.xticks(range(1,11))
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.title('Elbow curve for customer data')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_51116\576045464.py in <module>
#       1 # Plot the elbow curve to find the best candidate(s) for k
# ----> 2 plt.plot(myopia_elbow['k'], myopia_elbow['inertia'])
#       3 plt.xticks(range(1,11))
#       4 plt.xlabel('Number of clusters')
#       5 plt.ylabel('Inertia')
#
# NameError: name 'myopia_elbow' is not defined

# %% [markdown]
# ### Part 4: Make a Recommendation

# %% [markdown]
# Based on the results, the patients can be clustered into 3 groups.
